# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
"""
c, n, k
epoch 0
Person ID  Wrong  Total  Percentage
C      1      335      0.2985074626865672
E      4      962      0.4158004158004158
K      630      630      100.0
N      167      1156      14.446366782006919
c      397      400      99.25
n      247      957      25.809822361546498
epoch 1
Person ID  Wrong  Total  Percentage
C      59      335      17.611940298507463
E      4      962      0.4158004158004158
I      1      1095      0.091324200913242
J      4      474      0.8438818565400843
K      628      630      99.68253968253968
N      86      1156      7.439446366782007
O      7      1097      0.6381039197812215
P      1      963      0.10384215991692627
ZB      1      1551      0.06447453255963895
b      2      409      0.4889975550122249
c      211      400      52.75
n      360      957      37.61755485893417
w      1      493      0.2028397565922921
epoch 2
Person ID  Wrong  Total  Percentage
C      24      335      7.164179104477612
E      4      962      0.4158004158004158
K      630      630      100.0
N      256      1156      22.145328719723185
c      348      400      87.0
n      171      957      17.86833855799373
epoch 3
Person ID  Wrong  Total  Percentage
E      4      962      0.4158004158004158
K      630      630      100.0
N      386      1156      33.391003460207614
c      395      400      98.75
g      1      109      0.9174311926605505
n      643      957      67.18913270637408
#------------------------------------------------


 --- Epoch: 0, train loss: 0.0670, train acc: 0.9916, f1 score: 0.9916,  time: 24.190235137939453

/w0/tmp/slurm_ko617013.34291507/ipykernel_24307/2623334364.py:117: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
  if rowsOfWrongClassifications == []:

Epoch: 0, test loss: 0.4724, test acc: 0.8751, f1score: 0.8749, time: 31.897177696228027


 --- Epoch: 1, train loss: 0.0085, train acc: 0.9987, f1 score: 0.9987,  time: 55.11501407623291

/w0/tmp/slurm_ko617013.34291507/ipykernel_24307/2623334364.py:117: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
  if rowsOfWrongClassifications == []:

Epoch: 1, test loss: 0.3696, test acc: 0.8820, f1score: 0.8819, time: 62.87263560295105


 --- Epoch: 2, train loss: 0.0038, train acc: 0.9993, f1 score: 0.9993,  time: 85.79073405265808

/w0/tmp/slurm_ko617013.34291507/ipykernel_24307/2623334364.py:117: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
  if rowsOfWrongClassifications == []:

Epoch: 2, test loss: 0.6562, test acc: 0.8762, f1score: 0.8760, time: 93.41861748695374


 --- Epoch: 3, train loss: 0.0017, train acc: 0.9997, f1 score: 0.9997,  time: 116.39946460723877

/w0/tmp/slurm_ko617013.34291507/ipykernel_24307/2623334364.py:117: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
  if rowsOfWrongClassifications == []:

Epoch: 3, test loss: 0.9446, test acc: 0.8221, f1score: 0.8221, time: 124.27289414405823

#--------------------------------------------------------------------------------------
e, g, d
epoch 0
Person ID  Wrong  Total  Percentage
D      35      179      19.553072625698324
E      3      962      0.31185031185031187
G      3      499      0.6012024048096193
L      6      732      0.819672131147541
S      1      487      0.20533880903490762
T      1      933      0.10718113612004287
ZA      2      621      0.322061191626409
b      1      409      0.24449877750611246
c      1      400      0.25
d      10      1005      0.9950248756218906
e      749      1000      74.9
g      94      109      86.23853211009175
o      1      671      0.14903129657228018
u      1      510      0.19607843137254902
w      1      493      0.2028397565922921
epoch 1
Person ID  Wrong  Total  Percentage
D      6      179      3.35195530726257
E      660      962      68.60706860706861
G      9      499      1.8036072144288577
d      360      1005      35.82089552238806
g      109      109      100.0
epoch 2
Person ID  Wrong  Total  Percentage
D      10      179      5.58659217877095
E      11      962      1.1434511434511436
G      217      499      43.48697394789579
b      2      409      0.4889975550122249
d      920      1005      91.54228855721394
e      1000      1000      100.0
g      109      109      100.0
o      1      671      0.14903129657228018
epoch 3
Person ID  Wrong  Total  Percentage
D      2      179      1.1173184357541899
DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
  if rowsOfWrongClassifications == []:

Epoch: 3, test loss: 0.5841, test acc: 0.8403, f1score: 0.8405, time: 123.68328619003296


"""

# %%
import matplotlib.pyplot as plt

import matplotlib.colors as mc

import pandas as pd

"""
############
# CNK
############
epoch 0
Person ID  Wrong  Total  Percentage
C      1      335      0.2985074626865672
E      4      962      0.4158004158004158
K      630      630      100.0
N      167      1156      14.446366782006919
c      397      400      99.25
n      247      957      25.809822361546498
"""

persons_CNK_E0 = ['C', 'E', 'K', 'N', 'c', 'n']
percentage_CNK_E0 = [0.30, 0.41, 100.0, 14.45, 99.25, 25.81]

df_CNK_E0 = pd.DataFrame()
df_CNK_E0["person"] = persons_CNK_E0
df_CNK_E0["percentage"] = percentage_CNK_E0
#print(df_CNK_E0)

"""
epoch 1
Person ID  Wrong  Total  Percentage
C      59      335      17.611940298507463
E      4      962      0.4158004158004158
I      1      1095      0.091324200913242
J      4      474      0.8438818565400843
K      628      630      99.68253968253968
N      86      1156      7.439446366782007
O      7      1097      0.6381039197812215
P      1      963      0.10384215991692627
ZB      1      1551      0.06447453255963895
b      2      409      0.4889975550122249
c      211      400      52.75
n      360      957      37.61755485893417
w      1      493      0.2028397565922921
"""

persons_CNK_E1 = ['C', 'E', 'I','J', 'K', 'N','O','P', 'ZB','b', 'c', 'n', 'w']
percentage_CNK_E1 = [17.61, 0.42, 0.09, 0.84, 99.68, 7.44, 0.64, 0.10, 0.06, 0.49, 52.75, 37.62, 0.20]

df_CNK_E1 = pd.DataFrame()
df_CNK_E1["person"] = persons_CNK_E1
df_CNK_E1["percentage"] = percentage_CNK_E1
#print(df_CNK_E1)

"""
epoch 2
Person ID  Wrong  Total  Percentage
C      24      335      7.164179104477612
E      4      962      0.4158004158004158
K      630      630      100.0
N      256      1156      22.145328719723185
c      348      400      87.0
n      171      957      17.86833855799373
"""
persons_CNK_E2 = ['C', 'E', 'K', 'N', 'c', 'n']
percentage_CNK_E2 = [7.16, 0.42, 100.0, 22.14, 87.0, 17.87]

df_CNK_E2 = pd.DataFrame()
df_CNK_E2["person"] = persons_CNK_E2
df_CNK_E2["percentage"] = percentage_CNK_E2
#print(df_CNK_E2)

"""
epoch 3
Person ID  Wrong  Total  Percentage
E      4      962      0.4158004158004158
K      630      630      100.0
N      386      1156      33.391003460207614
c      395      400      98.75
g      1      109      0.9174311926605505
n      643      957      67.18913270637408
"""
persons_CNK_E3 = ['E', 'K', 'N','c', 'g', 'n']
percentage_CNK_E3 = [0.41, 100.0, 33.39, 98.75, 0.92, 67.19]

df_CNK_E3 = pd.DataFrame()
df_CNK_E3["person"] = persons_CNK_E3
df_CNK_E3["percentage"] = percentage_CNK_E3
#print(df_CNK_E3)


#plotting barchart of epochs
colors0 = ["red" if ((i == 'C') or (i == 'N') or (i == 'K') or (i == 'c') or (i == 'n') or (i == 'k')) else "yellow" for i in persons_CNK_E0]
colors1 = ["red" if ((i == 'C') or (i == 'N') or (i == 'K') or (i == 'c') or (i == 'n') or (i == 'k')) else "yellow" for i in persons_CNK_E1]
colors2 = ["red" if ((i == 'C') or (i == 'N') or (i == 'K') or (i == 'c') or (i == 'n') or (i == 'k')) else "yellow" for i in persons_CNK_E2]
colors3 = ["red" if ((i == 'C') or (i == 'N') or (i == 'K') or (i == 'c') or (i == 'n') or (i == 'k')) else "yellow" for i in persons_CNK_E3]

#fig, ax = plt.subplots(1, 4, figsize=(4, 4))

#plt.figure(figsize=(2,2))

plt.subplot(1, 4, 1)
plt.barh(persons_CNK_E0, percentage_CNK_E0, color=colors0)
plt.xlabel('Percent Wrong')
plt.ylabel('Person')
plt.title('CNK Epoch 0')

plt.subplot(1, 4, 2)
plt.barh(persons_CNK_E1, percentage_CNK_E1, color=colors1)
plt.xlabel('Percent Wrong')
plt.ylabel('Person')
plt.title('CNK Epoch 1')

plt.subplot(1, 4, 3)
plt.barh(persons_CNK_E2, percentage_CNK_E2, color=colors2)
plt.xlabel('Percent Wrong')
plt.ylabel('Person')
plt.title('CNK Epoch 2')

plt.subplot(1, 4, 4)
plt.barh(persons_CNK_E3, percentage_CNK_E3, color=colors3)
plt.xlabel('Percent Wrong')
plt.ylabel('Person')
plt.title('CNK Epoch 3')

plt.subplots_adjust(bottom=0.2, wspace=0.9)
plt.show()


#----------------------------------
############
# O P ZB
############

"""
epoch 0
Person ID  Wrong  Total  Percentage
B      1      315      0.31746031746031744
D      16      179      8.938547486033519
E      5      962      0.5197505197505198
I      6      1095      0.547945205479452
M      1      777      0.1287001287001287
N      11      1156      0.9515570934256056
O      192      1097      17.502278942570648
P      522      963      54.20560747663551
Q      23      562      4.092526690391459
R      1      204      0.49019607843137253
S      29      487      5.95482546201232
U      21      420      5.0
Y      1      1112      0.08992805755395684
ZB      217      1551      13.99097356544165
ZC      120      1346      8.915304606240714
o      12      671      1.7883755588673622
w      4      493      0.8113590263691683
zb      503      1237      40.662894098625706
"""

persons_OPZB_E0 = ['B', 'D', 'E', 'I', 'M', 'N', 'O', 'P', 'Q', 'R', 'S', 'U', 'Y', 'ZB', 'ZC', 'o', 'w', 'zb']
percentage_OPZB_E0 = [0.32, 8.94, 0.52, 0.55, 0.13, 0.95, 17.50, 54.21, 4.09, 0.49, 5.95, 5.0, 0.09, 13.99, 8.92, 1.79, 0.81, 40.66]

df_OPZB_E0 = pd.DataFrame()
df_OPZB_E0["person"] = persons_OPZB_E0
df_OPZB_E0["percentage"] = percentage_OPZB_E0

"""
epoch 1
Person ID  Wrong  Total  Percentage
C      5      335      1.4925373134328357
E      49      962      5.093555093555094
I      3      1095      0.273972602739726
O      250      1097      22.789425706472198
P      2      963      0.20768431983385255
Q      2      562      0.3558718861209964
S      1      487      0.20533880903490762
Y      1      1112      0.08992805755395684
ZB      412      1551      26.563507414571248
ZC      1      1346      0.07429420505200594
c      7      400      1.7500000000000002
d      1      1005      0.09950248756218905
n      5      957      0.522466039707419
o      20      671      2.9806259314456036
p      190      190      100.0
s      4      457      0.87527352297593
w      2      493      0.4056795131845842
zb      68      1237      5.497170573969281
"""
persons_OPZB_E1 = ['C', 'E', 'I', 'O', 'P', 'Q', 'S', 'Y', 'ZB', 'ZC', 'c', 'd', 'n', 'o', 'p', 's', 'w', 'zb']
percentage_OPZB_E1 = [1.49, 5.09, 0.27, 22.79, 0.20, 0.36, 0.21, 0.09, 26.56, 0.07, 1.75, 0.10, 0.52, 2.98, 100.0, 0.88, 0.40, 5.50]

df_OPZB_E1 = pd.DataFrame()
df_OPZB_E1["person"] = persons_OPZB_E1
df_OPZB_E1["percentage"] = percentage_OPZB_E1

"""
epoch 2
Person ID  Wrong  Total  Percentage
P      114      963      11.838006230529595
ZB      166      1551      10.702772404900065
e      1      1000      0.1
o      669      671      99.70193740685544
p      24      190      12.631578947368421
u      1      510      0.19607843137254902
zb      185      1237      14.955537590945836
"""

persons_OPZB_E2 = ['P', 'ZB', 'e', 'o', 'p', 'u', 'zb']
percentage_OPZB_E2 = [11.84, 10.70, 0.10, 99.70, 12.63, 0.20, 14.96]

df_OPZB_E2 = pd.DataFrame()
df_OPZB_E2["person"] = persons_OPZB_E2
df_OPZB_E2["percentage"] = percentage_OPZB_E2

"""
epoch 3
Person ID  Wrong  Total  Percentage
O      2      1097      0.18231540565177756
P      169      963      17.549325025960542
ZB      810      1551      52.22437137330754
e      1      1000      0.1
o      667      671      99.40387481371089
p      99      190      52.10526315789473
zb      315      1237      25.464834276475344
zc      1      1288      0.07763975155279502
"""

persons_OPZB_E3 = ['O', 'P', 'ZB', 'e', 'o', 'p', 'zb', 'zc']
percentage_OPZB_E3 = [0.18, 17.55, 52.22, 0.1, 99.40, 52.11, 25.46, 0.08]

df_OPZB_E3 = pd.DataFrame()
df_OPZB_E3["person"] = persons_OPZB_E3
df_OPZB_E3["percentage"] = percentage_OPZB_E3

#plotting barchart of epochs
colors0 = ["red" if ((i == 'O') or (i == 'P') or (i == 'ZB') or (i == 'o') or (i == 'p') or (i == 'zb')) else "yellow" for i in persons_OPZB_E0]
colors1 = ["red" if ((i == 'O') or (i == 'P') or (i == 'ZB') or (i == 'o') or (i == 'p') or (i == 'zb')) else "yellow" for i in persons_OPZB_E1]
colors2 = ["red" if ((i == 'O') or (i == 'P') or (i == 'ZB') or (i == 'o') or (i == 'p') or (i == 'zb')) else "yellow" for i in persons_OPZB_E2]
colors3 = ["red" if ((i == 'O') or (i == 'P') or (i == 'ZB') or (i == 'o') or (i == 'p') or (i == 'zb')) else "yellow" for i in persons_OPZB_E3]

#fig, ax = plt.subplots(1, 4, figsize=(4, 4))

#plt.figure(figsize=(2,2))

plt.subplot(1, 4, 1)
plt.barh(persons_OPZB_E0, percentage_OPZB_E0, color=colors0)
plt.xlabel('Percent Wrong')
plt.ylabel('Person')
plt.title('OPZB Epoch 0')

plt.subplot(1, 4, 2)
plt.barh(persons_OPZB_E1, percentage_OPZB_E1, color=colors1)
plt.xlabel('Percent Wrong')
plt.ylabel('Person')
plt.title('OPZB Epoch 1')

plt.subplot(1, 4, 3)
plt.barh(persons_OPZB_E2, percentage_OPZB_E2, color=colors2)
plt.xlabel('Percent Wrong')
plt.ylabel('Person')
plt.title('OPZB Epoch 2')

plt.subplot(1, 4, 4)
plt.barh(persons_OPZB_E3, percentage_OPZB_E3, color=colors3)
plt.xlabel('Percent Wrong')
plt.ylabel('Person')
plt.title('OPZB Epoch 3')

plt.subplots_adjust(bottom=0.2, wspace=0.9)
plt.show()


#----------------------------------
############
# 
############
